# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('lost_code.csv')

# %%
df.rename(columns={df.columns[0]: 'instruction'}, inplace= True)

# %%
df.loc[0, '0']
# Out:
# 4815162342

# %%
nums_array = np.random.randint(999999999, 9999999999, size=(500, 1))
nums_array
# Out:
# array([[3925682326],
#        [8098000380],
#        [4012148863],
#        [1507283315],
#        [5212286945],
#        [2041707756],
#        [3049532686],
#        [6151800562],
#        [3608568171],
#        [5137198288],
#        [6219800155],
#        [5896961615],
#        [8808038829],
#        [5036071526],
#        [5578317393],
#        [3616743125],
#        [1944551815],
#        [1576979443],
#        [7230405635],
#        [4026059864],
#        [8577565318],
#        [1246076756],
#        [2150664589],
#        [6224327223],
#        [9313337261],
#        [4050204237],
#        [2363813108],
#        [9755521176],
#        [7724746204],
#        [9637853169],
#        [9901339330],
#        [2634712975],
#        [4324213973],
#        [7476001296],
#        [2898987734],
#        [1119335186],
#        [1327707621],
#        [8366908502],
#        [7590242626],
#        [4326713474],
#        [6334843301],
#        [3447502620],
#        [4822012433],
# ...

# %%
for i in nums_array:
    print(len(str(i[0])))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# ...

# %%
nums_array[125] = 4815162342

# %%
nums_array
# Out:
# array([[3925682326],
#        [8098000380],
#        [4012148863],
#        [1507283315],
#        [5212286945],
#        [2041707756],
#        [3049532686],
#        [6151800562],
#        [3608568171],
#        [5137198288],
#        [6219800155],
#        [5896961615],
#        [8808038829],
#        [5036071526],
#        [5578317393],
#        [3616743125],
#        [1944551815],
#        [1576979443],
#        [7230405635],
#        [4026059864],
#        [8577565318],
#        [1246076756],
#        [2150664589],
#        [6224327223],
#        [9313337261],
#        [4050204237],
#        [2363813108],
#        [9755521176],
#        [7724746204],
#        [9637853169],
#        [9901339330],
#        [2634712975],
#        [4324213973],
#        [7476001296],
#        [2898987734],
#        [1119335186],
#        [1327707621],
#        [8366908502],
#        [7590242626],
#        [4326713474],
#        [6334843301],
#        [3447502620],
#        [4822012433],
# ...

# %%
pd.DataFrame(nums_array, columns= ['instruction']).to_csv('lost_code.csv')
